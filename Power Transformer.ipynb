# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.preproceswsing import PowerTransformer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 from sklearn.preproceswsing import PowerTransformer
#
# ModuleNotFoundError: No module named 'sklearn.preproceswsing'
