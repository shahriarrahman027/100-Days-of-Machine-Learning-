# %%
import numpy as np
import pandas as pd

# %%
date=pd.read_csv('orders.csv')
time=pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date=date.drop(columns=['product_id' ,'city_id' ,'orders'])

# %%
date.head()
# Out:
#          date
# 0  2019-12-10
# 1  2018-08-15
# 2  2018-10-23
# 3  2019-08-17
# 4  2019-01-06

# %%
time=time.drop(columns=['msg'])
time.head()
# Out:
#                   date
# 0  2013-12-15 00:50:00
# 1  2014-04-29 23:40:00
# 2  2012-12-30 00:21:00
# 3  2014-11-28 00:31:00
# 4  2013-10-26 23:11:00

# %%
date.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 7.9 KB

# %%
time.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   str
# dtypes: str(1)
# memory usage: 7.9 KB

# %%
# Converting the datatype of date and time

# %%
date['date']=pd.to_datetime(date['date'])

# %%
time['date']=pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 7.9 KB

# %% [markdown]
# ## Working with the date

# %%
#extract year,month,date:
date['date_year']=date['date'].dt.year
date['date_month']=date['date'].dt.month
date['date_month_name']=date['date'].dt.month_name()
date['date_day']=date['date'].dt.day
date['date_day_name']=date['date'].dt.day_name()
date['day_of_week']=date['date'].dt.dayofweek

date.head()
# Out:
#         date  date_year  date_month  date_day date_month_name  day_of_week  \
# 0 2019-12-10       2019          12        10        December            1
# 1 2018-08-15       2018           8        15          August            2
# 2 2018-10-23       2018          10        23         October            1
# 3 2019-08-17       2019           8        17          August            5
# 4 2019-01-06       2019           1         6         January            6
#
#    date_is_weekend date_day_name
# 0                0       Tuesday
# 1                0     Wednesday
# 2                0       Tuesday
# 3                0      Saturday
# 4                0        Sunday

# %% [markdown]
# ### is this a weekend?

# %%
date['date_is_weekend']=np.where(date['date_day_name'].isin(['Friday','Saturday']),1,0)

# %%
date.sample(10)
# Out:
#           date  date_year  date_month  date_day date_month_name  day_of_week  \
# 954 2019-06-21       2019           6        21            June            4
# 811 2018-11-03       2018          11         3        November            5
# 575 2018-09-27       2018           9        27       September            3
# 310 2018-11-20       2018          11        20        November            1
# 65  2019-03-27       2019           3        27           March            2
# 225 2019-04-26       2019           4        26           April            4
# 262 2018-11-14       2018          11        14        November            2
# 78  2019-05-28       2019           5        28             May            1
# 910 2019-04-25       2019           4        25           April            3
# 840 2019-03-29       2019           3        29           March            4
#
#      date_is_weekend date_day_name
# 954                1        Friday
# 811                1      Saturday
# ...
