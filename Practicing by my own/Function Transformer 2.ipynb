# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %%
df= pd.read_csv("Social_Network_Ads.csv")

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df=df.drop(columns=['User ID','Gender'])

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X=df.iloc[:,0:2]
X.head()
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            20000
# 2   26            43000
# 3   27            57000
# 4   19            76000

# %%
y=df.iloc[:,2]
y.sample(10)
# Out:
# 51     0
# 171    0
# 150    0
# 124    0
# 14     0
# 369    1
# 87     0
# 196    0
# 284    0
# 223    1
# Name: Purchased, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)
X_train.head(), X_test.head()
# Out:
# (     Age  EstimatedSalary
#  3     27            57000
#  18    46            28000
#  202   39           134000
#  250   44            39000
#  274   57            26000,
#       Age  EstimatedSalary
#  209   46            22000
#  280   59            88000
#  33    28            44000
#  210   48            96000
#  93    29            28000)

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.kdeplot(X_train["Age"])
plt.title("Age PDF")

plt.subplot(122)
stats.probplot(X_train["Age"], dist="norm", plot=plt)
plt.title("QQ plot for age")
plt.show()

# %%
# this is look like normal. so we not need to transform this

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.kdeplot(X_train["EstimatedSalary"])
plt.title("Estimeted Salary PDF")

plt.subplot(122)
stats.probplot(X_train["EstimatedSalary"], dist="norm", plot=plt)
plt.title("QQ plot for Estimeted Salary")
plt.show()

# %%
lr=LogisticRegression()
dtc=DecisionTreeClassifier()

# %%
lr.fit(X_train,y_train)
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=lr.predict(X_test)
y_pred2=dtc.predict(X_test)

# %%
print("Accuracy of LR: ",accuracy_score(y_test,y_pred))
print("Accuracy of DT: ",accuracy_score(y_test,y_pred2))
# Out:
# Accuracy of LR:  0.8875
# Accuracy of DT:  0.8375

# %% [markdown]
# # Log transform

# %%
trf=FunctionTransformer(func=np.log1p)

# %%
trf.fit(X_train)
# Out:
# FunctionTransformer(func=<ufunc 'log1p'>)

# %%
X_train_transformed = trf.transform(X_train)
X_test_transformed= trf.transform(X_test)

# %%
stats.probplot(X_train_transformed["EstimatedSalary"], dist= "norm", plot=plt)
plt.title("QQ plot for transformed Estimated Salary ")
plt.show()

# %%
lr.fit(X_train_transformed,y_train)
# Out:
# LogisticRegression()

# %%
y_pred= lr.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.35
