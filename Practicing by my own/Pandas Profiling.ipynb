# %%
import pandas as pd

# %%
df=pd.read_csv("cars.csv")
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
pip install ydata_profiling
# Out:
# Requirement already satisfied: ydata_profiling in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (2.1.4)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (1.26.4)
# Requirement already satisfied: minify-html>=0.15.0 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (2.33.1)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from ydata_profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from imagehash==4.3.2->ydata_profiling) (1.9.0)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from imagehash==4.3.2->ydata_profiling) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from jinja2<3.2,>=3.1.6->ydata_profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from numba<0.63,>=0.60->ydata_profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2026.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2026.2)
# Requirement already satisfied: joblib>=0.14.1 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from phik<0.13,>=0.12.5->ydata_profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from pydantic<3,>=2->ydata_profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from pydantic<3,>=2->ydata_profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from pydantic<3,>=2->ydata_profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from pydantic<3,>=2->ydata_profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata_profiling) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata_profiling) (2026.5.20)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.2)
# Requirement already satisfied: attrs>=19.3.0 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (3.6.1)
# Requirement already satisfied: puremagic in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (1.30)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata_profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport
# Out:
# /opt/anaconda3/envs/mlenv/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# /var/folders/_3/_rwv4p4533q_lf0cclgbfdv80000gn/T/ipykernel_87385/44057814.py:1: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
prof=ProfileReport(df)

# %%
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1699.47it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/mlenv/bin/python
