# %%
import pandas as pd

# %%
df=pd.read_csv('Titanic.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# Collecting scipy<1.17,>=1.8 (from ydata-profiling)
#   Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting pandas!=1.4.0,<3.0,>1.5 (from ydata-profiling)
#   Downloading pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling)
#   Downloading matplotlib-3.10.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting pydantic<3,>=2 (from ydata-profiling)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Collecting numpy<2.4,>=1.22 (from ydata-profiling)
#   Downloading numpy-2.3.5-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.18.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling)
#   Downloading phik-0.12.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from ydata-profiling) (2.33.1)
# Collecting tqdm<5,>=4.66.3 (from ydata-profiling)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.6-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting typeguard<5,>=4 (from ydata-profiling)
#   Downloading typeguard-4.5.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.2 (from ydata-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata-profiling)
#   Downloading wordcloud-1.9.6-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Collecting dacite<2,>=1.9 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<0.63,>=0.60 (from ydata-profiling)
#   Downloading numba-0.62.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from imagehash==4.3.2->ydata-profiling)
#   Downloading pywavelets-1.9.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.6 kB)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from imagehash==4.3.2->ydata-profiling) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba<0.63,>=0.60->ydata-profiling)
#   Downloading llvmlite-0.45.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (4.8 kB)
# Collecting pytz>=2020.1 (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling)
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting joblib>=0.14.1 (from phik<0.13,>=0.12.5->ydata-profiling)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2->ydata-profiling)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=2->ydata-profiling)
#   Downloading pydantic_core-2.46.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=2->ydata-profiling)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.5.20)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: attrs>=19.3.0 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (26.1.0)
# Collecting networkx>=2.4 (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-2.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/firstlearining/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading matplotlib-3.10.0-cp313-cp313-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 1.1 MB/s  0:00:07m0:00:0100:010m
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.62.1-cp313-cp313-macosx_12_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 1.2 MB/s  0:00:02 eta 0:00:01
# Downloading llvmlite-0.45.1-cp313-cp313-macosx_12_0_arm64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 1.1 MB/s  0:00:33m0:00:0100:010m
# Downloading numpy-2.3.5-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 1.2 MB/s  0:00:04 eta 0:00:01
# Downloading pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 1.1 MB/s  0:00:09m0:00:0100:01
# Downloading phik-0.12.5-cp313-cp313-macosx_11_0_arm64.whl (666 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 666.9/666.9 kB 1.2 MB/s  0:00:00 eta 0:00:01
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp313-cp313-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 1.2 MB/s  0:00:01 eta 0:00:01
# Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 1.1 MB/s  0:00:19m0:00:0100:01
# Downloading statsmodels-0.14.6-cp313-cp313-macosx_11_0_arm64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 1.2 MB/s  0:00:08m0:00:010:01
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typeguard-4.5.2-py3-none-any.whl (36 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading minify_html-0.18.1-cp313-cp313-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 526.5 kB/s  0:00:05 eta 0:00:01
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.1 MB/s  0:00:01 eta 0:00:010m
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Downloading wordcloud-1.9.6-cp313-cp313-macosx_11_0_arm64.whl (168 kB)
# Downloading puremagic-2.2.0-py3-none-any.whl (71 kB)
# Downloading pywavelets-1.9.0-cp313-cp313-macosx_11_0_arm64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 1.2 MB/s  0:00:03 eta 0:00:01
# Installing collected packages: pytz, minify-html, filetype, tzdata, typing-inspection, typeguard, tqdm, pydantic-core, puremagic, numpy, networkx, multimethod, llvmlite, joblib, dacite, annotated-types, scipy, PyWavelets, pydantic, patsy, pandas, numba, visions, statsmodels, matplotlib, imagehash, wordcloud, phik, ydata-profiling
#   Attempting uninstall: numpym━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/29 [tqdm]ype]
#     Found existing installation: numpy 2.4.4━━━━━━━━━━━━━━━━━━  6/29 [tqdm]
#     Uninstalling numpy-2.4.4:╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/29 [numpy]
#       Successfully uninstalled numpy-2.4.4━━━━━━━━━━━━━━━━━━━━  9/29 [numpy]
#   Attempting uninstall: scipy╸━━━━━━━━━━━━━━━━━━━━━━ 13/29 [joblib]e]
#     Found existing installation: scipy 1.17.1━━━━━━━━━━━━━━━━━ 13/29 [joblib]
#     Uninstalling scipy-1.17.1:╺━━━━━━━━━━━━━━━━━ 16/29 [scipy]
#       Successfully uninstalled scipy-1.17.10m━━━━━━━━━━━━━━━━━ 16/29 [scipy]
#   Attempting uninstall: pandas━━━━╺━━━━━━━━━━━━━ 19/29 [patsy]ic]s]
#     Found existing installation: pandas 3.0.2━━━━━━━━━━━━━ 19/29 [patsy]
#     Uninstalling pandas-3.0.2:━━━━━╸━━━━━━━━━━━━ 20/29 [pandas]
#       Successfully uninstalled pandas-3.0.20m━━━━━━━━━━━━ 20/29 [pandas]
#   Attempting uninstall: matplotlib━━━━━╸━━━━━━━━ 23/29 [statsmodels]
#     Found existing installation: matplotlib 3.10.9━━━━━━━━ 23/29 [statsmodels]
#     Uninstalling matplotlib-3.10.9:╸━━━━━━━━ 23/29 [statsmodels]
#       Successfully uninstalled matplotlib-3.10.90m╺━━━━━━ 24/29 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [ydata-profiling] [ydata-profiling]
# Successfully installed PyWavelets-1.9.0 annotated-types-0.7.0 dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 joblib-1.5.3 llvmlite-0.45.1 matplotlib-3.10.0 minify-html-0.18.1 multimethod-1.12 networkx-3.6.1 numba-0.62.1 numpy-2.3.5 pandas-2.3.3 patsy-1.0.2 phik-0.12.5 puremagic-2.2.0 pydantic-2.13.4 pydantic-core-2.46.4 pytz-2026.2 scipy-1.16.3 statsmodels-0.14.6 tqdm-4.67.3 typeguard-4.5.2 typing-inspection-0.4.2 tzdata-2026.2 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 16/16 [00:00<00:00, 204.53it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/mlenv/bin/python
